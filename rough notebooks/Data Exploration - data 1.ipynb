# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

# %%
df1 = pd.read_csv('./data/CMO_MSP_Mandi.csv')
df1.head()
# Out:
#          commodity  year          Type  msprice  msp_filter
# 0   PADDY-UNHUSKED  2012  Kharif Crops   1250.0           1
# 1  RICE(PADDY-HUS)  2012  Kharif Crops   1280.0           1
# 2     Jowar_Hybrid  2012  Kharif Crops   1500.0           1
# 3    SORGUM(JAWAR)  2012  Kharif Crops   1520.0           1
# 4            BAJRI  2012  Kharif Crops   1175.0           1

# %%
df1.shape
# Out:
# (155, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 5 columns):
# commodity     155 non-null object
# year          155 non-null int64
# Type          155 non-null object
# msprice       145 non-null float64
# msp_filter    155 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 6.1+ KB

# %%
df1.commodity.unique().size
# Out:
# 32

# %%
df1.year.unique().size
# Out:
# 5

# %%
df1.Type.unique().size
# Out:
# 3

# %%
df1.msp_filter.unique().size
# Out:
# 1

# %%
df1.msprice.plot()

# %% [raw]
# Upon taking an overview of the dataset "CMO_MSP_Mandi.csv", it was found that there 32 unique crops, and the data was collected for five years. Also the attributes msprice has 10 missing values and the attribute msp_filter it supposedly of no use right now.

# %%
sorteddf = df1.sort_values(by=['commodity', 'year'])
sorteddf.head(155)
# Out:
#                   commodity  year          Type  msprice  msp_filter
# 4                     BAJRI  2012  Kharif Crops   1175.0           1
# 35                    BAJRI  2013  Kharif Crops   1310.0           1
# 66                    BAJRI  2014  Kharif Crops   1250.0           1
# 97                    BAJRI  2015  Kharif Crops   1275.0           1
# 128                   BAJRI  2016  Kharif Crops   1330.0           1
# 20                    BARLI  2012    Rabi Crops    980.0           1
# 51                    BARLI  2013    Rabi Crops   1100.0           1
# 82                    BARLI  2014    Rabi Crops   1150.0           1
# 113                   BARLI  2015    Rabi Crops   1225.0           1
# 144                   BARLI  2016    Rabi Crops      NaN           1
# 28                  COCONUT  2012   Other Crops   1400.0           1
# 59                  COCONUT  2013   Other Crops   1425.0           1
# 90                  COCONUT  2014   Other Crops   1425.0           1
# ...

# %% [markdown]
# I could see some errors in the commodity names, for example the commodity SUGARCANE is also fed as SUGAR-CANE.

# %%
sorteddf.commodity.unique()
# Out:
# array(['BAJRI', 'BARLI', 'COCONUT', 'COTTON', 'Copra (Ball)_Yellow',
#        'Copra (Milling)_Yellow', 'Cotton_Long Staple', 'GR.NUT KERNELS',
#        'Gram_Yellow', 'Jowar_Hybrid', 'Jute_Yellow', 'MAIZE', 'MUSTARD',
#        'Masur_Yellow', 'NIGER-SEED', 'PADDY-UNHUSKED', 'PIGEON PEA (TUR)',
#        'RICE(PADDY-HUS)', 'Ragi_Maldandi', 'SAFFLOWER', 'SESAMUM',
#        'SORGUM(JAWAR)', 'SOYABEAN', 'SPILT GERRN GRAM',
#        'SPLIT BLACK GRAM', 'SUGAR-CANE', 'SUGARCANE', 'SUNFLOWER',
#        'Soyabean_Black', 'Toria_Yellow', 'WHEAT(HUSKED)',
#        'WHEAT(UNHUSKED)'], dtype=object)

# %%
sorteddf.commodity = sorteddf.commodity.apply(lambda x: x.upper().replace('_', ' ')).replace(to_replace='SUGAR-CANE', value='SUGARCANE').replace(to_replace='SPILT GERRN GRAM', value='SPLIT GREEN GRAM')

sorteddf.commodity.unique()
# Out:
# array(['BAJRI', 'BARLI', 'COCONUT', 'COTTON', 'COPRA (BALL) YELLOW',
#        'COPRA (MILLING) YELLOW', 'COTTON LONG STAPLE', 'GR.NUT KERNELS',
#        'GRAM YELLOW', 'JOWAR HYBRID', 'JUTE YELLOW', 'MAIZE', 'MUSTARD',
#        'MASUR YELLOW', 'NIGER-SEED', 'PADDY-UNHUSKED', 'PIGEON PEA (TUR)',
#        'RICE(PADDY-HUS)', 'RAGI MALDANDI', 'SAFFLOWER', 'SESAMUM',
#        'SORGUM(JAWAR)', 'SOYABEAN', 'SPLIT GREEN GRAM',
#        'SPLIT BLACK GRAM', 'SUGARCANE', 'SUNFLOWER', 'SOYABEAN BLACK',
#        'TORIA YELLOW', 'WHEAT(HUSKED)', 'WHEAT(UNHUSKED)'], dtype=object)

# %%
df = sorteddf
df.head(155)
# Out:
#                   commodity  year          Type  msprice  msp_filter
# 4                     BAJRI  2012  Kharif Crops   1175.0           1
# 35                    BAJRI  2013  Kharif Crops   1310.0           1
# 66                    BAJRI  2014  Kharif Crops   1250.0           1
# 97                    BAJRI  2015  Kharif Crops   1275.0           1
# 128                   BAJRI  2016  Kharif Crops   1330.0           1
# 20                    BARLI  2012    Rabi Crops    980.0           1
# 51                    BARLI  2013    Rabi Crops   1100.0           1
# 82                    BARLI  2014    Rabi Crops   1150.0           1
# 113                   BARLI  2015    Rabi Crops   1225.0           1
# 144                   BARLI  2016    Rabi Crops      NaN           1
# 28                  COCONUT  2012   Other Crops   1400.0           1
# 59                  COCONUT  2013   Other Crops   1425.0           1
# 90                  COCONUT  2014   Other Crops   1425.0           1
# ...

# %%
print(df.commodity.unique().size)
# Out:
# 31

# %%
df.iloc[df.msprice==NaN]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-8d8d6374ac1a> in <module>
# ----> 1 df.iloc[df.msprice==NaN]
#
# NameError: name 'NaN' is not defined

# %%
df[df.isnull().any(axis=1)]
# Out:
#            commodity  year          Type  msprice  msp_filter
# 144            BARLI  2016    Rabi Crops      NaN           1
# 145      GRAM YELLOW  2016    Rabi Crops      NaN           1
# 147          MUSTARD  2016    Rabi Crops      NaN           1
# 146     MASUR YELLOW  2016    Rabi Crops      NaN           1
# 148        SAFFLOWER  2016    Rabi Crops      NaN           1
# 107   SOYABEAN BLACK  2015  Kharif Crops      NaN           1
# 138   SOYABEAN BLACK  2016  Kharif Crops      NaN           1
# 149     TORIA YELLOW  2016    Rabi Crops      NaN           1
# 142    WHEAT(HUSKED)  2016    Rabi Crops      NaN           1
# 143  WHEAT(UNHUSKED)  2016    Rabi Crops      NaN           1

# %%
df.ffill()
# Out:
#                   commodity  year          Type  msprice  msp_filter
# 4                     BAJRI  2012  Kharif Crops   1175.0           1
# 35                    BAJRI  2013  Kharif Crops   1310.0           1
# 66                    BAJRI  2014  Kharif Crops   1250.0           1
# 97                    BAJRI  2015  Kharif Crops   1275.0           1
# 128                   BAJRI  2016  Kharif Crops   1330.0           1
# 20                    BARLI  2012    Rabi Crops    980.0           1
# 51                    BARLI  2013    Rabi Crops   1100.0           1
# 82                    BARLI  2014    Rabi Crops   1150.0           1
# 113                   BARLI  2015    Rabi Crops   1225.0           1
# 144                   BARLI  2016    Rabi Crops   1225.0           1
# 28                  COCONUT  2012   Other Crops   1400.0           1
# 59                  COCONUT  2013   Other Crops   1425.0           1
# 90                  COCONUT  2014   Other Crops   1425.0           1
# ...

# %%
sb.lineplot(data=df, x='year', y='msprice', hue='commodity', )

# %%
count =
